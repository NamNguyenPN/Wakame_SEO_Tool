# %%
# TRƯỚC TIÊN HÃY CÀI CÁC GÓI PACKAGES SAU ĐÂY BẰNG LỆNH DƯỚI ĐÂY #
#             pip install selenium, wmi, netifaces               #

# %% [raw]
# # class SEO:
# #     def __init__(self):
# #         self.driver=None
# #         self.home_path=None
# #         pass
# #     def delay(self,times):
# #         time.sleep(times)
# #     def edge(self,object):
# #         self.driver=webdriver.Edge(executable_path="msedgedriver.exe")
# #         self.driver.maximize_window()
# #         self.driver.get("https://www.google.com")
# #     def chrome(self,object):
# #         self.driver=webdriver.Chrome()
# #         self.driver.maximize_window()
# #         if object == None:
# #             self.driver.get("https://www.google.com")
# #         else:
# #             self.driver.get(object)
# #     def back(self):
#
# #         self.driver.back()
# #     def quit(self):
# #         self.driver.quit()
# #         self.driver=None
# #     def get_driver(self):
# #         return self.driver
#
#
# #     def search(self,key_words):
# #         self.driver.implicitly_wait(300)
# #         search_box=self.driver.find_element(By.NAME,'q')
# #         search_box.click()
# #         for letter in key_words:
# #             search_box.send_keys(letter)
# #             speed=rd.uniform(0,1.5)
# #             self.delay(speed)
# #         search_box.send_keys(Keys.ENTER)
# #     def sc_down(self):
# #         self.driver.implicitly_wait(300)
# #         height=self.driver.execute_script("return document.body.scrollHeight")
# #         for i in range(0,height):
# #             script="window.scrollTo(0,"+str(i)+")"
# #             self.driver.execute_script(script)
# #     def sc_up(self):
# #         self.driver.implicitly_wait(300)
# #         height=self.driver.execute_script("return document.body.scrollHeight")
# #         for i in range(0,height):
# #             script="window.scrollTo(0,"+str(height-i)+")"
# #             self.driver.execute_script(script)
# #     def rank(self,object):
# #         if object == None:
# #             href="https://wakame-uit.online"
# #         for i in range(1,10):
# #             xpath="//*[@id='rso']/div["+str(i)+"]/div/div/div[1]/a"
# #             wakame=self.driver.find_element(By.XPATH,xpath)
# #             if(wakame.get_attribute('href')=="https://wakame-uit.online/"):
# #                 print("Top",i,"trong tìm kiếm của Google")
# #                 return i,wakame
# #         print("Ngoài top 10 trong tìm kiếm Google")
# #         return None,None
# #     def toPage(self):
# #         self.driver.implicitly_wait(300)
# #         index,page=self.rank(self)
# #         if(page != None):
# #             page.click()
#
# #     def toTop(self):
# #         self.driver.implicitly_wait(300)
# #         back_top_path='//*[@id="back-top"]/a'
# #         back_top=self.driver.find_element(By.XPATH,back_top_path)
# #         back_top.click()
#
# #     def read(self):
# #         self.driver.implicitly_wait(300)
# #         height=self.driver.execute_script("return document.body.scrollHeight")
# #         for i in range(0,height):
# #             script="window.scrollTo(0,"+str(i)+")"
# #             self.driver.execute_script(script)
# #             self.delay(0.08)
#
# #     def Home(self):
# #         self.driver.implicitly_wait(300)
# #         home_path='//*[@id="navigation"]/li[1]/a'
# #         home=self.driver.find_element(By.XPATH,home_path)
# #         home.click()
#
# #     def News(self):
# #         self.driver.implicitly_wait(100)
# #         news_path="//*[@id='navigation']/li[4]/a"
# #         news=self.driver.find_element(By.XPATH,news_path)
# #         news.click()
#
# #     def search_box(self,key_words):
# #         search_box_path="/html/body/main/section[2]/div/div/div[2]/div/aside[1]/form/div/div/input"
# #         search_box=self.driver.find_element(By.XPATH,search_box_path)
# #         search_box.click()
# #         for letter in key_words:
# #             search_box.send_keys(letter)
# #             speed=rd.uniform(0,1.5)
# #             self.delay(speed)
# #         search_box.send_keys(Keys.ENTER)
# # #    def ToContent(self):
# # #        self.driver.implicitly_wait(100)
# # #        content_path='/html/body/main/section[2]/div/div/div[2]/div/aside[3]/div/div/a'
# # #        content=self.driver.find_element(By.XPATH,content_path)
# # #        content.click()
#
# #     def Courses(self):
# #         self.driver.implicitly_wait(300)
# #         courses_path='//*[@id="navigation"]/li[2]/a'
# #         courses=self.driver.find_element(By.XPATH,courses_path)
# #         courses.click()
#
# #     def About(self):
# #         self.driver.implicitly_wait(300)
# #         aboutus_path='//*[@id="navigation"]/li[5]/a'
# #         aboutus=self.driver.find_element(By.XPATH,aboutus_path)
# #         aboutus.click()

# %%
import pandas as pd
import time,datetime
import random as rd
from change_ip_mac import IP_MAC
from SEO import SEO

# %%
# TRƯỚC TIÊN HÃY CÀI CÁC GÓI PACKAGES SAU ĐÂY BẰNG DƯỚI ĐÂY #
# pip install selenium, wmi, netifaces #

####### Khởi tạo #######
a=SEO()
fake=IP_MAC()
report=pd.DataFrame(columns=[
    'Lần', 'Trạng thái', 'Địa chỉ IP', 
    'Địa chỉ MAC','Thời gian SEO',"Key_words"
])
########################


#Danh sách từ khóa (thương hiệu, thương mại)
KEYWORDS=["Clb Wakame","wakame uit","luyện thi jlpt wakame",
          "tin tức Wakame","các khóa học của wakame"
         ]
#Tổng số bài đăng trên web hiện tại
MAX=7
#Số lần thực hiện truy cập trang web
sl_truycap=20

#Khoảng thời gian dừng ở lại trang (không làm gì) từ 5s tới 20s tùy mọi setup
WAIT=[5,20]

#Random thời gian
def t():
    return rd.randint(WAIT[0],WAIT[1])

# %%
for i in range(sl_truycap):
    keywords=""
    try:
        #Thay đổi IP và MAC
        fake.__init__()
        fake.run()
        
        #Search từ khóa
        a.delay(5)
        a.chrome(None)
        a.delay(5)
        keywords=KEYWORDS[rd.randint(0,len(KEYWORDS)-1)]
        #keywords='các khóa học wakame'
        print(keywords)
        a.search(keywords) #Random từ khóa ngẫu nhiên
        a.delay(5)
        #a.search("Luyện thi JLPT Wakame")
        
        #Phần thao tác trên cửa trang tìm kiếm (Option)
        a.sc_down() #Cuộn trang xuống
        a.delay(3)
        a.sc_up()
        
        a.toPage() #Vào trang của mình (https://wakame-uit.online)
        #a.quit()
        
        st=time.time()    
        #Phần thao tác trên trang Wakame
        a.delay(5)
        
        a.sc_down()
        
        a.delay(t())
        
        a.toTop()
        
        a.delay(t())

        a.Home()         # Đi tới trang Tin tức
        
        a.sc_down()
        
        a.delay(5)
        
        a.News()
        
        a.delay(5)

        a.search_box("Văn hóa") #Chỉ thực hiện được khi đã ở trang Tin tức
        
        a.delay(5)

        a.News()         # Quay lại trang trước
        
        a.delay(t())
        
        a.toContent(MAX) # Chọn bài báo ngẫu nhiên để click (chỉ khi ở trang Tin tức)
        
        a.read()
        
        a.delay(t())
        
        a.toTop()
        
        a.delay(t())
        #### Kết thúc SEO ##
        fake.is_connect()
        
        a.quit()
        print("\n#### SEO lần",i+1,"thành công ####\n")
                
        report.loc[i]=[i+1,"Success",fake.get_IP(),fake.get_MAC(),str(datetime.timedelta(seconds=time.time()-st)),keywords]
    except:
        a.quit()
        report.loc[i]=[i+1,"Failed","---.---.---.---","--.--.--.--.--.--","--:--:--",keywords]
        print("\n#### SEO lần",i+1,"thất bại ####\n")
# Out:
# Sửa địa chỉ MAC trên Registry thành công: { 0A-44-89-15-75-43 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 0A-44-89-15-75-43 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.30
# IP Address:  192.168.1.30
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# các khóa học của wakame
# Top 2 trong tìm kiếm của Google
#
# #### SEO lần 1 thành công ####
#
# Lần                                    1
# Trạng thái                       Success
# Địa chỉ IP                  192.168.1.30
# Địa chỉ MAC            0A-44-89-15-75-43
# Thời gian SEO             0:06:00.897733
# Key_words        các khóa học của wakame
# Name: 0, dtype: object
# Sửa địa chỉ MAC trên Registry thành công: { 0E-66-28-40-86-48 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 0E-66-28-40-86-48 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.83
# IP Address:  192.168.1.83
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# các khóa học của wakame
# Top 2 trong tìm kiếm của Google
#
# #### SEO lần 2 thành công ####
#
# Lần                                    2
# Trạng thái                       Success
# Địa chỉ IP                  192.168.1.83
# Địa chỉ MAC            0E-66-28-40-86-48
# Thời gian SEO             0:03:43.251638
# Key_words        các khóa học của wakame
# Name: 1, dtype: object
# Sửa địa chỉ MAC trên Registry thành công: { 06-14-72-45-35-21 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 06-14-72-45-35-21 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.131
# IP Address:  192.168.1.131
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# luyện thi jlpt wakame
# Top 1 trong tìm kiếm của Google
#
# #### SEO lần 3 thành công ####
#
# Lần                                  3
# Trạng thái                     Success
# Địa chỉ IP               192.168.1.131
# Địa chỉ MAC          06-14-72-45-35-21
# Thời gian SEO           0:03:38.876754
# Key_words        luyện thi jlpt wakame
# Name: 2, dtype: object
# Sửa địa chỉ MAC trên Registry thành công: { 06-92-78-83-94-13 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 06-92-78-83-94-13 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.79
# IP Address:  192.168.1.79
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# wakame uit
# Top 3 trong tìm kiếm của Google
#
# #### SEO lần 4 thành công ####
#
# Lần                              4
# Trạng thái                 Success
# Địa chỉ IP            192.168.1.79
# Địa chỉ MAC      06-92-78-83-94-13
# Thời gian SEO       0:03:45.266309
# Key_words               wakame uit
# Name: 3, dtype: object
# Sửa địa chỉ MAC trên Registry thành công: { 0A-77-25-71-07-24 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 0A-77-25-71-07-24 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.79
# IP Address:  192.168.1.79
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# Clb Wakame
# Top 1 trong tìm kiếm của Google
#
# #### SEO lần 5 thành công ####
#
# Lần                              5
# Trạng thái                 Success
# Địa chỉ IP            192.168.1.79
# Địa chỉ MAC      0A-77-25-71-07-24
# Thời gian SEO       0:03:35.479136
# Key_words               Clb Wakame
# Name: 4, dtype: object
# Sửa địa chỉ MAC trên Registry thành công: { 02-30-02-88-45-11 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 02-30-02-88-45-11 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.117
# IP Address:  192.168.1.117
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# các khóa học của wakame
# Top 2 trong tìm kiếm của Google
#
# #### SEO lần 6 thành công ####
#
# Lần                                    6
# Trạng thái                       Success
# Địa chỉ IP                 192.168.1.117
# Địa chỉ MAC            02-30-02-88-45-11
# Thời gian SEO             0:03:24.237501
# Key_words        các khóa học của wakame
# Name: 5, dtype: object
# Sửa địa chỉ MAC trên Registry thành công: { 02-09-45-21-02-90 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 02-09-45-21-02-90 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.96
# IP Address:  192.168.1.96
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# các khóa học của wakame
# Top 2 trong tìm kiếm của Google
#
# #### SEO lần 7 thành công ####
#
# Lần                                    7
# Trạng thái                       Success
# Địa chỉ IP                  192.168.1.96
# Địa chỉ MAC            02-09-45-21-02-90
# Thời gian SEO             0:03:48.972482
# Key_words        các khóa học của wakame
# Name: 6, dtype: object
# Sửa địa chỉ MAC trên Registry thành công: { 06-76-55-23-83-92 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 06-76-55-23-83-92 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.5
# IP Address:  192.168.1.5
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# Clb Wakame
# Top 1 trong tìm kiếm của Google
#
# #### SEO lần 8 thành công ####
#
# Lần                              8
# Trạng thái                 Success
# Địa chỉ IP             192.168.1.5
# Địa chỉ MAC      06-76-55-23-83-92
# Thời gian SEO       0:03:24.563489
# Key_words               Clb Wakame
# Name: 7, dtype: object
# Sửa địa chỉ MAC trên Registry thành công: { 0A-39-70-77-30-32 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 0A-39-70-77-30-32 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.39
# IP Address:  192.168.1.39
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# Clb Wakame
# Top 1 trong tìm kiếm của Google
#
# #### SEO lần 9 thành công ####
#
# Lần                              9
# Trạng thái                 Success
# Địa chỉ IP            192.168.1.39
# Địa chỉ MAC      0A-39-70-77-30-32
# Thời gian SEO       0:03:29.052120
# Key_words               Clb Wakame
# Name: 8, dtype: object
# Sửa địa chỉ MAC trên Registry thành công: { 0A-28-06-44-57-08 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 0A-28-06-44-57-08 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.144
# IP Address:  192.168.1.144
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# luyện thi jlpt wakame
# Top 1 trong tìm kiếm của Google
#
# #### SEO lần 10 thành công ####
#
# Lần                                 10
# Trạng thái                     Success
# Địa chỉ IP               192.168.1.144
# Địa chỉ MAC          0A-28-06-44-57-08
# Thời gian SEO           0:03:26.409916
# Key_words        luyện thi jlpt wakame
# Name: 9, dtype: object
# Sửa địa chỉ MAC trên Registry thành công: { 0A-80-59-93-41-56 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 0A-80-59-93-41-56 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.89
# IP Address:  192.168.1.89
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# Clb Wakame
# Top 1 trong tìm kiếm của Google
#
# #### SEO lần 11 thành công ####
#
# Lần                             11
# Trạng thái                 Success
# Địa chỉ IP            192.168.1.89
# Địa chỉ MAC      0A-80-59-93-41-56
# Thời gian SEO       0:06:11.429579
# Key_words               Clb Wakame
# Name: 10, dtype: object
# Sửa địa chỉ MAC trên Registry thành công: { 06-72-57-09-34-99 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 06-72-57-09-34-99 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.120
# IP Address:  192.168.1.120
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# Clb Wakame
# Top 1 trong tìm kiếm của Google
#
# #### SEO lần 12 thành công ####
#
# Lần                             12
# Trạng thái                 Success
# Địa chỉ IP           192.168.1.120
# Địa chỉ MAC      06-72-57-09-34-99
# Thời gian SEO       0:04:06.749893
# Key_words               Clb Wakame
# Name: 11, dtype: object
# Sửa địa chỉ MAC trên Registry thành công: { 02-25-62-92-13-22 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 02-25-62-92-13-22 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.7
# IP Address:  192.168.1.7
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# wakame uit
# Top 3 trong tìm kiếm của Google
#
# #### SEO lần 13 thành công ####
#
# Lần                             13
# Trạng thái                 Success
# Địa chỉ IP             192.168.1.7
# Địa chỉ MAC      02-25-62-92-13-22
# Thời gian SEO       0:04:35.283181
# Key_words               wakame uit
# Name: 12, dtype: object
# Sửa địa chỉ MAC trên Registry thành công: { 06-89-51-64-75-05 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 06-89-51-64-75-05 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.61
# IP Address:  192.168.1.61
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# Clb Wakame
# Top 1 trong tìm kiếm của Google
#
# #### SEO lần 14 thành công ####
#
# Lần                             14
# Trạng thái                 Success
# Địa chỉ IP            192.168.1.61
# Địa chỉ MAC      06-89-51-64-75-05
# Thời gian SEO       0:05:53.376570
# Key_words               Clb Wakame
# Name: 13, dtype: object
# Sửa địa chỉ MAC trên Registry thành công: { 06-33-61-51-41-85 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 06-33-61-51-41-85 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.83
# IP Address:  192.168.1.83
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# luyện thi jlpt wakame
# Top 1 trong tìm kiếm của Google
#
# #### SEO lần 15 thành công ####
#
# Lần                                 15
# Trạng thái                     Success
# Địa chỉ IP                192.168.1.83
# Địa chỉ MAC          06-33-61-51-41-85
# Thời gian SEO           0:04:31.230947
# Key_words        luyện thi jlpt wakame
# Name: 14, dtype: object
# Sửa địa chỉ MAC trên Registry thành công: { 06-04-14-85-43-52 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 06-04-14-85-43-52 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.133
# IP Address:  192.168.1.133
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# luyện thi jlpt wakame
# Top 1 trong tìm kiếm của Google
#
# #### SEO lần 16 thành công ####
#
# Lần                                 16
# Trạng thái                     Success
# Địa chỉ IP               192.168.1.133
# Địa chỉ MAC          06-04-14-85-43-52
# Thời gian SEO           0:04:00.985660
# Key_words        luyện thi jlpt wakame
# Name: 15, dtype: object
# Sửa địa chỉ MAC trên Registry thành công: { 0A-16-46-09-74-87 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 0A-16-46-09-74-87 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.108
# IP Address:  192.168.1.108
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# các khóa học của wakame
# Top 1 trong tìm kiếm của Google
#
# #### SEO lần 17 thành công ####
#
# Lần                                   17
# Trạng thái                       Success
# Địa chỉ IP                 192.168.1.108
# Địa chỉ MAC            0A-16-46-09-74-87
# Thời gian SEO             0:03:28.922599
# Key_words        các khóa học của wakame
# Name: 16, dtype: object
# Sửa địa chỉ MAC trên Registry thành công: { 06-44-66-23-39-99 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 06-44-66-23-39-99 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.136
# IP Address:  192.168.1.136
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# luyện thi jlpt wakame
# Top 1 trong tìm kiếm của Google
#
# #### SEO lần 18 thành công ####
#
# Lần                                 18
# Trạng thái                     Success
# Địa chỉ IP               192.168.1.136
# Địa chỉ MAC          06-44-66-23-39-99
# Thời gian SEO           0:03:27.708094
# Key_words        luyện thi jlpt wakame
# Name: 17, dtype: object
# Sửa địa chỉ MAC trên Registry thành công: { 02-81-15-36-06-42 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 02-81-15-36-06-42 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.125
# IP Address:  192.168.1.125
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# wakame uit
# Top 5 trong tìm kiếm của Google
#
# #### SEO lần 19 thành công ####
#
# Lần                             19
# Trạng thái                 Success
# Địa chỉ IP           192.168.1.125
# Địa chỉ MAC      02-81-15-36-06-42
# Thời gian SEO       0:05:54.999722
# Key_words               wakame uit
# Name: 18, dtype: object
# Sửa địa chỉ MAC trên Registry thành công: { 02-25-49-42-81-24 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 02-25-49-42-81-24 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.29
# IP Address:  192.168.1.29
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# các khóa học của wakame
# Top 6 trong tìm kiếm của Google
#
# #### SEO lần 20 thành công ####
#
# Lần                                   20
# Trạng thái                       Success
# Địa chỉ IP                  192.168.1.29
# Địa chỉ MAC            02-25-49-42-81-24
# Thời gian SEO             0:04:45.962384
# Key_words        các khóa học của wakame
# Name: 19, dtype: object

# %%
report
# Out:
#    Lần Trạng thái     Địa chỉ IP        Địa chỉ MAC   Thời gian SEO  \
# 0    1    Success   192.168.1.30  0A-44-89-15-75-43  0:06:00.897733
# 1    2    Success   192.168.1.83  0E-66-28-40-86-48  0:03:43.251638
# 2    3    Success  192.168.1.131  06-14-72-45-35-21  0:03:38.876754
# 3    4    Success   192.168.1.79  06-92-78-83-94-13  0:03:45.266309
# 4    5    Success   192.168.1.79  0A-77-25-71-07-24  0:03:35.479136
# 5    6    Success  192.168.1.117  02-30-02-88-45-11  0:03:24.237501
# 6    7    Success   192.168.1.96  02-09-45-21-02-90  0:03:48.972482
# 7    8    Success    192.168.1.5  06-76-55-23-83-92  0:03:24.563489
# 8    9    Success   192.168.1.39  0A-39-70-77-30-32  0:03:29.052120
# 9   10    Success  192.168.1.144  0A-28-06-44-57-08  0:03:26.409916
# 10  11    Success   192.168.1.89  0A-80-59-93-41-56  0:06:11.429579
# 11  12    Success  192.168.1.120  06-72-57-09-34-99  0:04:06.749893
# 12  13    Success    192.168.1.7  02-25-62-92-13-22  0:04:35.283181
# 13  14    Success   192.168.1.61  06-89-51-64-75-05  0:05:53.376570
# 14  15    Success   192.168.1.83  06-33-61-51-41-85  0:04:31.230947
# 15  16    Success  192.168.1.133  06-04-14-85-43-52  0:04:00.985660
# 16  17    Success  192.168.1.108  0A-16-46-09-74-87  0:03:28.922599
# 17  18    Success  192.168.1.136  06-44-66-23-39-99  0:03:27.708094
# 18  19    Success  192.168.1.125  02-81-15-36-06-42  0:05:54.999722
# 19  20    Success   192.168.1.29  02-25-49-42-81-24  0:04:45.962384
#
#                   Key_words
# 0   các khóa học của wakame
# 1   các khóa học của wakame
# 2     luyện thi jlpt wakame
# 3                wakame uit
# 4                Clb Wakame
# 5   các khóa học của wakame
# 6   các khóa học của wakame
# 7                Clb Wakame
# 8                Clb Wakame
# 9     luyện thi jlpt wakame
# 10               Clb Wakame
# 11               Clb Wakame
# 12               wakame uit
# 13               Clb Wakame
# 14    luyện thi jlpt wakame
# 15    luyện thi jlpt wakame
# 16  các khóa học của wakame
# 17    luyện thi jlpt wakame
# 18               wakame uit
# 19  các khóa học của wakame
