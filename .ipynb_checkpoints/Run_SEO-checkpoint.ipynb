# %%
# TRƯỚC TIÊN HÃY CÀI CÁC GÓI PACKAGES SAU ĐÂY BẰNG LỆNH DƯỚI ĐÂY #
#             pip install selenium, wmi, netifaces               #

# %% [raw]
# # class SEO:
# #     def __init__(self):
# #         self.driver=None
# #         self.home_path=None
# #         pass
# #     def delay(self,times):
# #         time.sleep(times)
# #     def edge(self,object):
# #         self.driver=webdriver.Edge(executable_path="msedgedriver.exe")
# #         self.driver.maximize_window()
# #         self.driver.get("https://www.google.com")
# #     def chrome(self,object):
# #         self.driver=webdriver.Chrome()
# #         self.driver.maximize_window()
# #         if object == None:
# #             self.driver.get("https://www.google.com")
# #         else:
# #             self.driver.get(object)
# #     def back(self):
#
# #         self.driver.back()
# #     def quit(self):
# #         self.driver.quit()
# #         self.driver=None
# #     def get_driver(self):
# #         return self.driver
#
#
# #     def search(self,key_words):
# #         self.driver.implicitly_wait(300)
# #         search_box=self.driver.find_element(By.NAME,'q')
# #         search_box.click()
# #         for letter in key_words:
# #             search_box.send_keys(letter)
# #             speed=rd.uniform(0,1.5)
# #             self.delay(speed)
# #         search_box.send_keys(Keys.ENTER)
# #     def sc_down(self):
# #         self.driver.implicitly_wait(300)
# #         height=self.driver.execute_script("return document.body.scrollHeight")
# #         for i in range(0,height):
# #             script="window.scrollTo(0,"+str(i)+")"
# #             self.driver.execute_script(script)
# #     def sc_up(self):
# #         self.driver.implicitly_wait(300)
# #         height=self.driver.execute_script("return document.body.scrollHeight")
# #         for i in range(0,height):
# #             script="window.scrollTo(0,"+str(height-i)+")"
# #             self.driver.execute_script(script)
# #     def rank(self,object):
# #         if object == None:
# #             href="https://wakame-uit.online"
# #         for i in range(1,10):
# #             xpath="//*[@id='rso']/div["+str(i)+"]/div/div/div[1]/a"
# #             wakame=self.driver.find_element(By.XPATH,xpath)
# #             if(wakame.get_attribute('href')=="https://wakame-uit.online/"):
# #                 print("Top",i,"trong tìm kiếm của Google")
# #                 return i,wakame
# #         print("Ngoài top 10 trong tìm kiếm Google")
# #         return None,None
# #     def toPage(self):
# #         self.driver.implicitly_wait(300)
# #         index,page=self.rank(self)
# #         if(page != None):
# #             page.click()
#
# #     def toTop(self):
# #         self.driver.implicitly_wait(300)
# #         back_top_path='//*[@id="back-top"]/a'
# #         back_top=self.driver.find_element(By.XPATH,back_top_path)
# #         back_top.click()
#
# #     def read(self):
# #         self.driver.implicitly_wait(300)
# #         height=self.driver.execute_script("return document.body.scrollHeight")
# #         for i in range(0,height):
# #             script="window.scrollTo(0,"+str(i)+")"
# #             self.driver.execute_script(script)
# #             self.delay(0.08)
#
# #     def Home(self):
# #         self.driver.implicitly_wait(300)
# #         home_path='//*[@id="navigation"]/li[1]/a'
# #         home=self.driver.find_element(By.XPATH,home_path)
# #         home.click()
#
# #     def News(self):
# #         self.driver.implicitly_wait(100)
# #         news_path="//*[@id='navigation']/li[4]/a"
# #         news=self.driver.find_element(By.XPATH,news_path)
# #         news.click()
#
# #     def search_box(self,key_words):
# #         search_box_path="/html/body/main/section[2]/div/div/div[2]/div/aside[1]/form/div/div/input"
# #         search_box=self.driver.find_element(By.XPATH,search_box_path)
# #         search_box.click()
# #         for letter in key_words:
# #             search_box.send_keys(letter)
# #             speed=rd.uniform(0,1.5)
# #             self.delay(speed)
# #         search_box.send_keys(Keys.ENTER)
# # #    def ToContent(self):
# # #        self.driver.implicitly_wait(100)
# # #        content_path='/html/body/main/section[2]/div/div/div[2]/div/aside[3]/div/div/a'
# # #        content=self.driver.find_element(By.XPATH,content_path)
# # #        content.click()
#
# #     def Courses(self):
# #         self.driver.implicitly_wait(300)
# #         courses_path='//*[@id="navigation"]/li[2]/a'
# #         courses=self.driver.find_element(By.XPATH,courses_path)
# #         courses.click()
#
# #     def About(self):
# #         self.driver.implicitly_wait(300)
# #         aboutus_path='//*[@id="navigation"]/li[5]/a'
# #         aboutus=self.driver.find_element(By.XPATH,aboutus_path)
# #         aboutus.click()

# %%
import pandas as pd
import time,datetime
import random as rd
from change_ip_mac import IP_MAC
from SEO import SEO

# %%
# TRƯỚC TIÊN HÃY CÀI CÁC GÓI PACKAGES SAU ĐÂY BẰNG DƯỚI ĐÂY #
# pip install selenium, wmi, netifaces #

####### Khởi tạo #######
a=SEO()
fake=IP_MAC()
report=pd.DataFrame(columns=[
    'Lần', 'Trạng thái', 'Địa chỉ IP', 
    'Địa chỉ MAC','Thời gian SEO',"Key_words"
])
########################


#Danh sách từ khóa (thương hiệu, thương mại)
KEYWORDS=["Clb Wakame","wakame uit","uit wakame","luyện thi jlpt wakame UIT",
          "tin tức Wakame","các khóa học của wakame"
         ]
#Tổng số bài đăng trên web hiện tại
MAX=7
#Số lần thực hiện truy cập trang web
sl_truycap=10

#Khoảng thời gian dừng ở lại trang (không làm gì) từ 5s tới 20s tùy mọi setup
WAIT=[10,30]

#Random thời gian
def t():
    return rd.randint(WAIT[0],WAIT[1])

# %%
for i in range(sl_truycap):
    keywords="-----------"
    try:
        #Thay đổi IP và MAC
        fake.__init__()
        fake.run()
        
        #Search từ khóa
        a.delay(5)
        a.edge(None)
        a.delay(5)
        keywords=KEYWORDS[rd.randint(0,len(KEYWORDS)-1)]
        #keywords='các khóa học wakame'
        print(keywords)
        a.search(keywords) #Random từ khóa ngẫu nhiên
        a.delay(5)
        #a.search("Luyện thi JLPT Wakame")
        
        #Phần thao tác trên cửa trang tìm kiếm (Option)
        a.sc_down() #Cuộn trang xuống
        a.delay(3)
        a.sc_up()
        
        a.toPage() #Vào trang của mình (https://wakame-uit.online)
        #a.quit()
        
        st=time.time()    
        #Phần thao tác trên trang Wakame
        a.delay(5)
        
        a.sc_down()
        
        a.delay(t())
        
        a.toTop()
        
        a.delay(t())

        a.Home()         # Đi tới trang Tin tức
        
        a.sc_down()
        
        a.delay(5)
        
        a.News()
        
        a.delay(5)

        a.search_box("Văn hóa") #Chỉ thực hiện được khi đã ở trang Tin tức
        
        a.delay(5)

        a.News()         # Quay lại trang trước
        
        a.delay(t())
        
        a.toContent(MAX) # Chọn bài báo ngẫu nhiên để click (chỉ khi ở trang Tin tức)
        
        a.read(0.01)
        
        a.delay(t())
        
        a.News()
        
        a.delay(t())
        
        a.toContent(MAX)
        
        a.read(0.01)
        
        a.News()
        
        a.delay(t())
        
        a.toContent(MAX)
        
        a.read(0.01)
        
        a.toTop()
        
        a.delay(t())
        #### Kết thúc SEO ##
        fake.is_connect()
        
        a.quit()
        print("\n#### SEO lần",i+1,"thành công ####\n")
                
        report.loc[i]=[i+1,"Success",fake.get_IP(),fake.get_MAC(),str(datetime.timedelta(seconds=time.time()-st)),keywords]
    except:
        a.quit()
        report.loc[i]=[i+1,"Failed","---.---.---.---","--.--.--.--.--.--","--:--:--",keywords]
        print("\n#### SEO lần",i+1,"thất bại ####\n")
# Out:
# Sửa địa chỉ MAC trên Registry thành công: { 06-35-97-07-31-05 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 06-35-97-07-31-05 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.113
# IP Address:  192.168.1.113
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# tin tức Wakame
# search success
# Ngoài top 10 trong tìm kiếm Google
# ToPage Failed
#
# #### SEO lần 1 thất bại ####
#
# Sửa địa chỉ MAC trên Registry thành công: { 0A-86-08-42-07-01 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 0A-86-08-42-07-01 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.94
# IP Address:  192.168.1.94
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# tin tức Wakame
# search success
# Top 17 trong tìm kiếm của Google
# toPage success
# toTop success
# Home success
# News success
# search_box success
# News success
# toContent success
# News success
# toContent success
# News success
# next page success
# toContent success
# toTop success
#
# #### SEO lần 2 thành công ####
#
# Sửa địa chỉ MAC trên Registry thành công: { 0A-30-34-44-94-98 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 0A-30-34-44-94-98 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.29
# IP Address:  192.168.1.29
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# uit wakame
# search success
# Top 5 trong tìm kiếm của Google
# toPage success
# toTop success
# Home success
# News success
# search_box success
# News success
# next page success
# toContent success
# News success
# toContent success
# News success
# toContent success
# toTop success
#
# #### SEO lần 3 thành công ####
#
# Sửa địa chỉ MAC trên Registry thành công: { 02-68-25-85-12-12 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 02-68-25-85-12-12 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.134
# IP Address:  192.168.1.134
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# các khóa học của wakame
# search success
# Top 1 trong tìm kiếm của Google
# toPage success
# toTop success
# Home success
# News success
# search_box success
# News success
# toContent success
# News success
# toContent success
# News success
# next page success
# toContent success
# toTop success
#
# #### SEO lần 4 thành công ####
#
# Sửa địa chỉ MAC trên Registry thành công: { 0E-90-98-84-20-92 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 0E-90-98-84-20-92 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.21
# IP Address:  192.168.1.21
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# các khóa học của wakame
# search success
# Top 1 trong tìm kiếm của Google
# toPage success
# toTop success
# Home success
# News success
# search_box success
# News success
# toContent success
# News success
# next page success
# toContent success
# News success
# toContent success
# toTop success
#
# #### SEO lần 5 thành công ####
#
# Sửa địa chỉ MAC trên Registry thành công: { 06-39-66-88-28-86 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 06-39-66-88-28-86 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.109
# IP Address:  192.168.1.109
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# wakame uit
# search success
# Top 5 trong tìm kiếm của Google
#
# #### SEO lần 6 thất bại ####
#
# Sửa địa chỉ MAC trên Registry thành công: { 02-77-81-16-58-43 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 02-77-81-16-58-43 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.26
# IP Address:  192.168.1.26
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# tin tức Wakame
# search success
# Top 16 trong tìm kiếm của Google
# toPage success
# toTop success
# Home success
# News success
# search_box success
# News success
# next page success
# toContent success
# News success
# next page success
# toContent success
# News success
# next page success
# toContent success
# toTop success
#
# #### SEO lần 7 thành công ####
#
# Sửa địa chỉ MAC trên Registry thành công: { 06-58-15-95-52-95 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 06-58-15-95-52-95 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.41
# IP Address:  192.168.1.41
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# wakame uit
# search success
# Top 5 trong tìm kiếm của Google
# toPage success
# toTop success
# Home success
# News success
# search_box success
# News success
# toContent success
# News success
# toContent success
# News success
# toContent success
# toTop success
#
# #### SEO lần 8 thành công ####
#
# Sửa địa chỉ MAC trên Registry thành công: { 02-05-70-70-03-25 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 02-05-70-70-03-25 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.128
# IP Address:  192.168.1.128
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# uit wakame
# search success
# Top 5 trong tìm kiếm của Google
# toPage success
# toTop success
# Home success
# News success
# search_box success
# News success
# toContent success
# News success
# next page success
# toContent success
# News success
# next page success
# toContent success
# toTop success
#
# #### SEO lần 9 thành công ####
#
# Sửa địa chỉ MAC trên Registry thành công: { 0A-31-57-73-03-58 }
# Vô hiệu hóa 2      Intel(R) Wireless-AC 9462
# Kích hoạt 2      Intel(R) Wireless-AC 9462
# Chuyển đổi địa chỉ MAC thành công.
# Địa chỉ MAC mới: { 0A-31-57-73-03-58 }
# Wifi is connected
# Internet has connected
# Chuyển đổi IP thành công. IP mới: 192.168.1.106
# IP Address:  192.168.1.106
# Mask:  255.255.255.0
# Gateway:  192.168.1.1
# Wifi is connected
# Internet has connected
# uit wakame
# search success
# Top 5 trong tìm kiếm của Google
# toPage success
# toTop success
# Home success
# News success
# search_box success
# News success
# toContent success
# News success
# next page success
# toContent success
# News success
# toContent success
# toTop success
#
# #### SEO lần 10 thành công ####

# %%
report
# Out:
#   Lần Trạng thái       Địa chỉ IP        Địa chỉ MAC   Thời gian SEO  \
# 0   1     Failed  ---.---.---.---  --.--.--.--.--.--        --:--:--
# 1   2    Success     192.168.1.94  0A-86-08-42-07-01  0:09:54.725541
# 2   3    Success     192.168.1.29  0A-30-34-44-94-98  0:08:03.261351
# 3   4    Success    192.168.1.134  02-68-25-85-12-12  0:11:21.819963
# 4   5    Success     192.168.1.21  0E-90-98-84-20-92  0:08:57.173024
# 5   6     Failed  ---.---.---.---  --.--.--.--.--.--        --:--:--
# 6   7    Success     192.168.1.26  02-77-81-16-58-43  0:13:17.904110
# 7   8    Success     192.168.1.41  06-58-15-95-52-95  0:08:19.872174
# 8   9    Success    192.168.1.128  02-05-70-70-03-25  0:09:00.688678
# 9  10    Success    192.168.1.106  0A-31-57-73-03-58  0:10:24.597672
#
#                  Key_words
# 0           tin tức Wakame
# 1           tin tức Wakame
# 2               uit wakame
# 3  các khóa học của wakame
# 4  các khóa học của wakame
# 5               wakame uit
# 6           tin tức Wakame
# 7               wakame uit
# 8               uit wakame
# 9               uit wakame
